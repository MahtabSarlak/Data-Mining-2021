# %%
from google.colab import drive
  
# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install tqdm

from tqdm import tqdm_notebook as tqdm
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import re
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

import seaborn as sns
import sklearn
import scipy
from scipy.stats import spearmanr , pointbiserialr
import sklearn.model_selection
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn import metrics
from sklearn.metrics import classification_report
import math
from sklearn.cluster import KMeans
from sklearn.metrics import classification_report,confusion_matrix, ConfusionMatrixDisplay
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer, TfidfVectorizer
from sklearn import linear_model
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import precision_score, accuracy_score, recall_score
import matplotlib.pyplot as plt
from string import punctuation
import random
import scipy
from scipy.stats import spearmanr , pointbiserialr
from collections import Counter
import math
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (4.41.1)
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Data Set

# %%
data_file_name ="/content/drive/MyDrive/Colab Notebooks/CVision/FinalProject_part1_dataset.csv"
features = ['App Name', 'Category', 'Rating', 'Reviews', 'Installs', 'Size',
       'Price', 'Content Rating', 'Game_genre'] 
dataset = pd.read_csv(data_file_name)

# %%
print("Data : {}\n".format(dataset.shape))
print("Data colums :\n\n {}".format(dataset.columns))
dataset.head()
# Out:
# Data : (16488, 12)
#
# Data colums :
#
#  Index(['reviewId', 'userName', 'userImage', 'content', 'score',
#        'thumbsUpCount', 'reviewCreatedVersion', 'at', 'replyContent',
#        'repliedAt', 'sortOrder', 'appId'],
#       dtype='object')
#                                             reviewId  ...      appId
# 0  gp:AOqpTOG_sbrCnu0wRH51BoojyG2l9kL95QWpBJ7aC5W...  ...  com.anydo
# 1  gp:AOqpTOGogprOZWoMGnVn_mzQOAPaSfgB4ZZs1AhHXzE...  ...  com.anydo
# 2  gp:AOqpTOEzFNt68Pau8IeHhpKZa-zUJgpW4g59wB9SmqY...  ...  com.anydo
# 3  gp:AOqpTOH1svJ6WlbEzBJao-Z-bPslFlNlOmcKbf585YY...  ...  com.anydo
# 4  gp:AOqpTOFIEKcKU1pFc0FJrQAsnGOIp8kQ4GYmMc93LWf...  ...  com.anydo
#
# [5 rows x 12 columns]

# %% [markdown]
# # PreProccessing and Visualization

# %%
print('Number of Contents per score')
display(dataset.score.value_counts())
fig=plt.figure(figsize=(8, 8))
a = sns.countplot(y = dataset.score,order = dataset.score.value_counts().index, data = dataset).set_title('Number of Contents per score')
# Out:
# Number of Contents per score
# 3    5246
# 5    3000
# 4    2866
# 1    2762
# 2    2614
# Name: score, dtype: int64

# %%
def preprocessing_content(X):
  documents = []
  lemmatizer= WordNetLemmatizer()
  stemmer= PorterStemmer()
  stop_words = set(stopwords.words('english'))
  for sen in range(0, len(X)):
      # Remove all the special characters
      document = re.sub(r'\W', ' ', str(X[sen]))
      
      # remove all single characters
      document = re.sub(r'\s+[a-zA-Z]\s+', ' ', document)
      
      # Remove single characters from the start
      document = re.sub(r'\^[a-zA-Z]\s+', ' ', document) 
      
      # Substituting multiple spaces with single space
      document = re.sub(r'\s+', ' ', document, flags=re.I)
      
      # Removing prefixed 'b'
      document = re.sub(r'^b\s+', '', document)
      
      # Converting to Lowercase
      document = document.lower()
      
      document = word_tokenize(document)
      
      # Lemmatization
      # document = [lemmatizer.lemmatize(word) for word in document]

      #stopword
      document = [i for i in document if not i in stop_words]
      
      documents.append(document)
  print(documents)
  return documents

# %%
processed_text = preprocessing_content(dataset['content'])
# Out:
# [['use', 'reminder', 'apps', 'one', 'thing', 'daily', 'reminders', 'happen', 'time', 'every', 'day', 'years', 'straight', 'miss', 'one', 'daily', 'reminders', 'big', 'deal', 'imagine', 'frustrated', 'become', 'one', 'daily', 'reminders', 'stops', 'notifying', 'happens', 'every', 'months', 'end', 'delete', 'repeating', 'reminder', 'create', 'anew', 'switched', 'built', 'google', 'reminders', 'problem', 'disappointed', 'app', 'overcome', 'challenge'], ['tired', 'constant', 'helpful', 'notifications', 'want', 'plan', 'day', 'want', 'reminded', 'buy', 'grocery', 'item', 'notifications', 'ok', 'option', 'turn', 'note', 'software', 'developers', 'assume', 'want', 'everyone', 'wants'], ['love', 'start', 'writing', 'task', 'switch', 'apps', 'go', 'back', 'writing', 'task', 'progress', 'subpanel', 'closed', 'task', 'save', 'current', 'state', 'likewise', 'writing', 'subtask', 'completing', 'switch', 'apps', 'options', 'subpanel', 'still', 'open', 'back', 'lose', 'subtasks', 'subpanel', 'must', 'manually', 'closed', 'super', 'annoying'], ['1', 'notes', 'take', 'long', 'sync', '2', 'see', 'entire', 'subtask', '3', 'erase', 'file', 'must', 'mark', 'task', 'complete', 'messing', 'productivity', 'rating', '4', 'reorder', 'tags', '5', 'turn', 'reminder', 'times', '6', 'app', 'good', 'idea', 'poorly', 'constructed'], ['keep', 'getting', 'last', 'month', 'message', 'app', 'responding', 'freezes', 'initial', 'page', 'switch', 'lists', 'things', 'created', 'add', 'subtract', 'various', 'lists', 'problems', 'happened', 'since', 'last', 'update', 'hope', 'fix', 'prob', 'soon'], ['app', 'excellent', 'dissapointed', 'freeze', 'nothing', 'else', 'paid', 'subscription', 'please', 'fix', 'problem', 'really', 'serious'], ['somehow', 'review', 'got', 'deleted', 'app', 'sync', 'properly', 'nwith', 'google', 'assistant', 'used', 'anymore', 'tried', 'everything', 'opted', 'switch', 'another', 'app', 'works', 'google', 'assistant'], ['loved', 'app', 'buggy', 'duplicates', 'subtasks', 'randomly', 'lose', 'subtask', 'click', 'strange', 'behaviour'], ['getting', 'worse', 'worse', 'buggier', 'buggier', 'update', 'tasks', 'subtasks', 'getting', 'completely', 'lost', 'due', 'bugs', 'even', 'features', 'bugs', 'nuisance', 'shame', 'really', 'solid', 'app', 'back', 'resorting', 'something', 'else', 'goodbye', 'thanks', 'good', 'years'], ['originally', 'gave', '2', 'star', 'think', 'deserves', '1', 'simply', 'wrap', 'head', 'around', 'following', 'picture', 'add', 'task', 'list', 'reminder', 'feature', 'want', 'change', 'time', 'reminder', 'feature', 'click', 'available', 'option', 'regards', 'changing', 'time', 'change', 'date', 'genius', 'advanced', 'application', 'even', 'bare', 'minimum', 'lmao'], ['simply', 'looking', 'widget', 'could', 'sync', 'calendars', 'email', 'addresses', 'sadly', 'despite', 'claims', 'description', 'seems', 'like', 'need', 'sign', 'another', 'service', 'zapier', 'something'], ['ugh', 'years', 'using', 'app', 'tired', 'reminders', 'syncing', 'across', 'media', 'get', 'notifications', 'task', 'chromebook', 'cellphone', 'tablet', 'dismiss', 'three', 'google', 'tasks', 'reminders', 'syncs', 'across', 'media', 'devices', 'create', 'lists', 'free', 'probably', 'kiss', 'goodbye', 'update', 'contacted', 'team', 'confirmed', 'sync', 'problem', 'time', 'solution'], ['good', 'updates', 'seem', 'make', 'things', 'worse', 'notified', 'tasks', 'natural', 'language', 'great', 'longer', 'removes', 'today', '1230pm', 'task', 'title', 'make', 'sense', 'snooze', 'task', 'til', '3pm', 'use', 'tomorrow', 'next', 'day', 'tasks', 'due', 'today', 'display', 'text', 'tomorrow', 'general', 'loss', 'confidence', 'upgrade'], ['new', 'user', 'think', 'app', 'great', 'try', 'first', 'time', 'already', 'find', 'app', 'working', 'entirely', 'well', 'put', 'task', 'today', 'appear', 'notification', 'bar', 'showing', 'detail', 'task', 'shows', 'today', 'tasks', 'arrow', 'besides', 'look', 'another', 'tasks', 'working', 'really', 'good', 'app', 'actually', 'hoping', 'fix' ...

# %% [markdown]
# # Word Embedding

# %%
def dummy_fun(doc):
    return doc
def tfidf(data, ma = 0.6, mi = 0.0001):
    tfidf_vectorize = TfidfVectorizer(
    analyzer='word',
    tokenizer=dummy_fun,
    preprocessor=dummy_fun,
    token_pattern=None,
    max_df = ma,
    min_df = mi) 
    tfidf_data = tfidf_vectorize.fit_transform(data)
    return tfidf_data

# %%
word_embedded_text = tfidf(processed_text)
print(word_embedded_text.shape)
# Out:
# (16488, 8127)

# %% [markdown]
# # Train Test split

# %%
def split_data(dataset_features, labels):
  # train 0.6 , test = 0.2 , val = 0.2
  x_train, x_test, y_train, y_test  = sklearn.model_selection.train_test_split(dataset_features, labels, test_size=0.2)
  # x_train, x_val, y_train, y_val = sklearn.model_selection.train_test_split(x_train, y_train, test_size=0.25) # 0.25 x 0.8 = 0.2
  print("X_train lenght: {}".format(x_train.shape[0]))
  print("X_test lenght: {}".format(x_test.shape[0]))
  # print("X_val lenght: {}".format(x_test.shape[0]))
  return x_train, x_test, y_train, y_test

# %%
labels = dataset['score']
x_train, x_test, y_train, y_test = split_data(word_embedded_text, labels)
# Out:
# X_train lenght: 13190
# X_test lenght: 3298

# %% [markdown]
# # model

# %% [markdown]
# ## Logestic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.pipeline import Pipeline
from tensorflow.keras.callbacks import ReduceLROnPlateau
def logistic_regression_model(x_train, x_test, y_train, y_test):

    model = Pipeline([ ('clf', LogisticRegression(n_jobs = 1 , C = 1e5))])
    classifier = model.fit(x_train,y_train)
    predictions = classifier.predict(x_test)
    print(classification_report(y_test, predictions))

    fig, ax = plt.subplots(figsize=(8, 8))
    plot_confusion_matrix(classifier, x_test, y_test, normalize='true', cmap=plt.cm.Blues, ax=ax)
    plt.show()

    return

# %%
logistic_regression_model(x_train, x_test, y_train, y_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
#               precision    recall  f1-score   support
#
#            1       0.68      0.66      0.67       552
#            2       0.60      0.62      0.61       554
#            3       0.63      0.69      0.66      1011
#            4       0.63      0.56      0.59       607
#            5       0.69      0.66      0.68       574
#
#     accuracy                           0.64      3298
#    macro avg       0.65      0.64      0.64      3298
# weighted avg       0.65      0.64      0.64      3298

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import SVC
def svm_model(x_train, x_test, y_train, y_test):
  svclassifier = SVC(kernel='linear')
  svclassifier.fit(x_train, y_train)
  y_pred = svclassifier.predict(x_test)
  cm = confusion_matrix(y_test,y_pred)
  print(classification_report(y_test,y_pred))

  fig, ax = plt.subplots(figsize=(8, 8))
  plot_confusion_matrix(svclassifier, x_test, y_test, normalize='true', cmap=plt.cm.Blues, ax=ax)
  plt.show()
  return

# %%
svm_model(x_train, x_test, y_train, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.59      0.59      0.59       523
#            2       0.55      0.30      0.38       558
#            3       0.51      0.74      0.60      1022
#            4       0.55      0.36      0.43       601
#            5       0.69      0.70      0.70       594
#
#     accuracy                           0.56      3298
#    macro avg       0.58      0.54      0.54      3298
# weighted avg       0.57      0.56      0.55      3298

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
def knn_model(x_train, x_test, y_train, y_test):
  classifier = KNeighborsClassifier(n_neighbors=5)
  classifier.fit(x_train, y_train)
  y_pred = classifier.predict(x_test)
  print(classification_report(y_test, y_pred))
  cm = confusion_matrix(y_test,y_pred)

  fig, ax = plt.subplots(figsize=(8, 8))
  plot_confusion_matrix(classifier, x_test, y_test, normalize='true', cmap=plt.cm.Blues, ax=ax)
  plt.show()
  return

# %%
knn_model(x_train, x_test, y_train, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.28      0.46      0.35       523
#            2       0.36      0.26      0.30       558
#            3       0.49      0.32      0.39      1022
#            4       0.41      0.18      0.25       601
#            5       0.28      0.51      0.36       594
#
#     accuracy                           0.34      3298
#    macro avg       0.36      0.35      0.33      3298
# weighted avg       0.38      0.34      0.34      3298

# %% [markdown]
# ## Clustering (K means)

# %%
def Kmeans(x_train, x_test, y_train, y_test):
        n_clusters = len(np.unique(y_train))
        clf = KMeans(n_clusters = n_clusters, random_state=42)
        clf.fit(x_train)
        y_pred = clf.predict(x_test)
        y_pred_new = [y+1 for y in y_pred]
        cm = confusion_matrix(y_test,y_pred)
        print(classification_report(y_test,y_pred))
        print(cm)
        return

# %%
Kmeans(x_train, x_test, y_train, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.04      0.00      0.00       523
#            2       0.16      0.15      0.15       558
#            3       0.35      0.02      0.04      1022
#            4       0.30      0.14      0.19       601
#            5       0.00      0.00      0.00       594
#
#     accuracy                           0.06      3298
#    macro avg       0.14      0.05      0.06      3298
# weighted avg       0.20      0.06      0.07      3298
#
# [[  0   0   0   0   0   0]
#  [443   1  64   2  13   0]
#  [450   1  83   5  19   0]
#  [785   7 169  23  38   0]
#  [371   6 120  22  82   0]
#  [363   8  92  14 117   0]]
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # 3 Class classification

# %%
logistic_regression_model(x_train, x_test, y_train, y_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
#               precision    recall  f1-score   support
#
#            1       0.62      0.64      0.63       523
#            2       0.58      0.53      0.55       558
#            3       0.60      0.63      0.61      1022
#            4       0.52      0.50      0.51       601
#            5       0.68      0.66      0.67       594
#
#     accuracy                           0.60      3298
#    macro avg       0.60      0.59      0.60      3298
# weighted avg       0.60      0.60      0.60      3298

# %%
svm_model(x_train, x_test, y_train, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.59      0.59      0.59       523
#            2       0.55      0.30      0.38       558
#            3       0.51      0.74      0.60      1022
#            4       0.55      0.36      0.43       601
#            5       0.69      0.70      0.70       594
#
#     accuracy                           0.56      3298
#    macro avg       0.58      0.54      0.54      3298
# weighted avg       0.57      0.56      0.55      3298

# %%
knn_model(x_train, x_test, y_train, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.28      0.46      0.35       523
#            2       0.36      0.26      0.30       558
#            3       0.49      0.32      0.39      1022
#            4       0.41      0.18      0.25       601
#            5       0.28      0.51      0.36       594
#
#     accuracy                           0.34      3298
#    macro avg       0.36      0.35      0.33      3298
# weighted avg       0.38      0.34      0.34      3298

# %%
Kmeans(x_train, x_test, y_train, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.04      0.00      0.00       523
#            2       0.16      0.15      0.15       558
#            3       0.35      0.02      0.04      1022
#            4       0.30      0.14      0.19       601
#            5       0.00      0.00      0.00       594
#
#     accuracy                           0.06      3298
#    macro avg       0.14      0.05      0.06      3298
# weighted avg       0.20      0.06      0.07      3298
#
# [[  0   0   0   0   0   0]
#  [443   1  64   2  13   0]
#  [450   1  83   5  19   0]
#  [785   7 169  23  38   0]
#  [371   6 120  22  82   0]
#  [363   8  92  14 117   0]]
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
